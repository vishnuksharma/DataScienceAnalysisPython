# %%
import pandas as pd, numpy as np

# %%
df = pd.read_csv('Delhi+Delights+Data.csv')
# df.info()

# %%
df.head(30)
# Out:
#     Average Delivery Rating (a1)  Average Orders per month (a2)  \
# 0                            1.5                             11
# 1                            2.5                             11
# 2                            2.5                             11
# 3                            3.5                             11
# 4                            3.5                             11
# 5                            4.5                             11
# 6                            1.5                             13
# 7                            2.5                             13
# 8                            2.5                             13
# 9                            3.5                             13
# 10                           3.5                             13
# 11                           4.5                             13
# 12                           1.5                             15
# 13                           2.5                             15
# ...

# %%
df1 = df[df['"Delighted Members" Purchase'] == 'Yes']

# %%
len(df1)
# Out:
# 15

# %%
a1_lessThree = df[df['Average Delivery Rating (a1)'] >= 3]

# %%
a1_lessThree
# Out:
#     Average Delivery Rating (a1)  Average Orders per month (a2)  \
# 3                            3.5                             11
# 4                            3.5                             11
# 5                            4.5                             11
# 9                            3.5                             13
# 10                           3.5                             13
# 11                           4.5                             13
# 15                           3.5                             15
# 16                           3.5                             15
# 17                           4.5                             15
# 21                           3.5                             27
# 22                           4.5                             27
# 23                           4.5                             27
# 27                           3.5                             39
# 28                           4.5                             39
# ...

# %%
a1_lessThree[a1_lessThree['"Delighted Members" Purchase'] == 'Yes']
# Out:
#     Average Delivery Rating (a1)  Average Orders per month (a2)  \
# 0                            1.5                             11
# 6                            1.5                             13
# 12                           1.5                             15
# 19                           2.5                             27
# 20                           2.5                             27
# 25                           2.5                             39
# 26                           2.5                             39
#
#    "Delighted Members" Purchase
# 0                           Yes
# 6                           Yes
# 12                          Yes
# 19                          Yes
# 20                          Yes
# 25                          Yes
# 26                          Yes

# %%
right = df[df['Average Orders per month (a2)'] < 20]
right
# Out:
#     Average Delivery Rating (a1)  Average Orders per month (a2)  \
# 0                            1.5                             11
# 1                            2.5                             11
# 2                            2.5                             11
# 3                            3.5                             11
# 4                            3.5                             11
# 5                            4.5                             11
# 6                            1.5                             13
# 7                            2.5                             13
# 8                            2.5                             13
# 9                            3.5                             13
# 10                           3.5                             13
# 11                           4.5                             13
# 12                           1.5                             15
# 13                           2.5                             15
# ...

# %%
right[(right['Average Delivery Rating (a1)'] == 4.5 or right['Average Delivery Rating (a1)'] == 1.5)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-ba20fc50a3f0> in <module>
# ----> 1 right[(right['Average Delivery Rating (a1)'] == 4.5 or right['Average Delivery Rating (a1)'] == 1.5)]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1477     def __nonzero__(self):
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1481         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
